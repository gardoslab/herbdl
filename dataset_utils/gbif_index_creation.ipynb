# %%
from constants import KAGGLE_HERBARIUM_21_TRAIN_CSV, KAGGLE_HERBARIUM_21_VAL_CSV, KAGGLE_HERBARIUM_22_TRAIN_CSV, KAGGLE_HERBARIUM_22_VAL_CSV, KAGGLE_HERBARIUM_21_TRAIN, KAGGLE_HERBARIUM_22_TRAIN, GBIF_HARVARD_MULTIMEDIA_DATA, GBIF_HARVARD_INSTALL_PATH
import pandas as pd
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Kaggle

# %%
kaggle22_train = pd.read_csv(KAGGLE_HERBARIUM_22_TRAIN_CSV).drop(columns=['Unnamed: 0'])
print(f"Number of training samples in Kaggle Herbarium 22: {len(kaggle22_train)}")
kaggle22_val = pd.read_csv(KAGGLE_HERBARIUM_22_VAL_CSV).drop(columns=['Unnamed: 0'])
print(f"Number of validation samples in Kaggle Herbarium 22: {len(kaggle22_val)}")

kaggle22 = pd.concat([kaggle22_train, kaggle22_val]).reset_index(drop=True)

kaggle22_file_paths = [os.path.join(KAGGLE_HERBARIUM_22_TRAIN, file) for file in kaggle22['filename'].tolist()]
print(f"Number of images in Kaggle Herbarium 22: {len(kaggle22_file_paths)}")

kaggle21_train = pd.read_csv(KAGGLE_HERBARIUM_21_TRAIN_CSV).drop(columns=['Unnamed: 0'])
print(f"Number of training samples in Kaggle Herbarium 21: {len(kaggle21_train)}")
kaggle21_val = pd.read_csv(KAGGLE_HERBARIUM_21_VAL_CSV).drop(columns=['Unnamed: 0'])
print(f"Number of validation samples in Kaggle Herbarium 21: {len(kaggle21_val)}")

kaggle21 = pd.concat([kaggle21_train, kaggle21_val]).reset_index(drop=True)

kaggle21_file_paths = [os.path.join(KAGGLE_HERBARIUM_21_TRAIN, file) for file in kaggle21['filename'].tolist()]
print(f"Number of images in Kaggle Herbarium 21 Train: {len(kaggle21_file_paths)}")

kaggle_df = pd.concat([kaggle21, kaggle22]).reset_index(drop=True)
print()
print(f"Total number of samples in Kaggle Herbarium 21 + 22: {len(kaggle_df)}")
# Out:
# Number of training samples in Kaggle Herbarium 22: 671817
# Number of validation samples in Kaggle Herbarium 22: 167955
# Number of images in Kaggle Herbarium 22: 839772
# Number of training samples in Kaggle Herbarium 21: 1806207
# Number of validation samples in Kaggle Herbarium 21: 451552
# Number of images in Kaggle Herbarium 21 Train: 2257759
#
# Total number of samples in Kaggle Herbarium 21 + 22: 3097531

# %%
# Out:
#   image_id            filename  \
# 0  1123740  494/80/1123740.jpg
# 1  1242345  161/93/1242345.jpg
# 2  2238072  069/53/2238072.jpg
# 3     1458     001/99/1458.jpg
# 4   344538   219/79/344538.jpg
#
#                                                                                                                                                         caption  \
# 0      This is an image of species mollis, in the genus Prestonia of family Apocynaceae. It is part of the collection of institution New York Botanical Garden.
# 1       This is an image of species parsonsia, in the genus Cuphea of family Lythraceae. It is part of the collection of institution New York Botanical Garden.
# 2  This is an image of species egensis, in the genus Bellucia of family Melastomataceae. It is part of the collection of institution New York Botanical Garden.
# 3              This is an image of species acradenia, in the genus Acacia of family Fabaceae. It is part of the collection of institution Queensland Herbarium.
# 4    This is an image of species halleanum, in the genus Epilobium of family Onagraceae. It is part of the collection of institution New York Botanical Garden.
#
#                      scientificName           family      genus    species  \
# 0      Apocynaceae Prestonia mollis      Apocynaceae  Prestonia     mollis
# 1       Lythraceae Cuphea parsonsia       Lythraceae     Cuphea  parsonsia
# 2  Melastomataceae Bellucia egensis  Melastomataceae   Bellucia    egensis
# 3         Fabaceae Acacia acradenia         Fabaceae     Acacia  acradenia
# 4    Onagraceae Epilobium halleanum       Onagraceae  Epilobium  halleanum
#
#    scientificNameEncoded
# 0                   3547
# 1                  34649
# 2                  36328
# 3                  24401
# 4                  41924

# %%
kaggle_df['scientificName'].nunique()
# Out:
# 64588

# %% [markdown]
# ## GBIF Harvard

# %%
harvard_gbif = pd.read_csv(GBIF_HARVARD_MULTIMEDIA_DATA, delimiter="\t", on_bad_lines='skip')
occurrence_df = pd.read_csv("/projectnb/herbdl/data/harvard-herbaria/gbif/occurrence.txt", delimiter="\t", on_bad_lines='warn')

print(f"Number of samples in Harvard GBIF dataset: {len(harvard_gbif)}")

# %%
occurrence_df.info()
# Out:
# Skipping line 17708: expected 223 fields, saw 250
#
# Skipping line 107317: expected 223 fields, saw 250
#
# Skipping line 392670: expected 223 fields, saw 250
#
# Skipping line 472416: expected 223 fields, saw 273
#
# Skipping line 483465: expected 223 fields, saw 250
#
# Skipping line 523925: expected 223 fields, saw 250
#
# Skipping line 677513: expected 223 fields, saw 250
#
# Skipping line 846378: expected 223 fields, saw 250
#
# Skipping line 907592: expected 223 fields, saw 250
#
# Skipping line 1077310: expected 223 fields, saw 250
#
# Skipping line 1365405: expected 223 fields, saw 250
#
# Skipping line 1408352: expected 223 fields, saw 250
#
# Skipping line 1447762: expected 223 fields, saw 273
#
# Skipping line 1452154: expected 223 fields, saw 250
#
# Skipping line 1739817: expected 223 fields, saw 273
#
# Skipping line 1769100: expected 223 fields, saw 273
#
# /scratch/545462.1.cds/ipykernel_689202/747113706.py:1: DtypeWarning: Columns (19,29,71,82,96,121,130,132,135,138,140,141,143,147,151,154,155,160,162,163,164,168,171,175,178,183,184,185,186,189,190,193,194,195,200,204,210,211) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/projectnb/herbdl/data/harvard-herbaria/gbif/occurrence.txt", delimiter="\t", on_bad_lines='warn')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1788293 entries, 0 to 1788292
# Columns: 223 entries, gbifID to iucnRedListCategory
# dtypes: float64(105), int64(1), object(117)
# memory usage: 3.0+ GB

# %%
occurrence_df = occurrence_df[['gbifID', 'family', 'genus', 'species']]
occurrence_df['species'] = occurrence_df['species'].str.split(' ').str[-1]

occurrence_df.head()
# Out:
#        gbifID            family          genus      species
# 0  1998934428       Orchidaceae       Galearis  spectabilis
# 1  2608676112     Lycopodiaceae       Spinulum    annotinum
# 2  1998934441        Asteraceae       Solidago      bicolor
# 3  1998442401      Papaveraceae   Ichtyoselmis    macrantha
# 4  1998934462  Brachytheciaceae  Brachythecium   conostomum

# %%
len(harvard_gbif) - (occurrence_df['gbifID'].isin(harvard_gbif['gbifID']).sum())
# Out:
# 28

# %%
harvard_df = harvard_gbif.merge(ccurrence_dff, on='gbifID', how='left')
harvard_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1537612 entries, 0 to 1537611
# Data columns (total 18 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   gbifID        1537612 non-null  int64
#  1   type          1537612 non-null  object
#  2   format        1537612 non-null  object
#  3   identifier    1537612 non-null  object
#  4   references    1537612 non-null  object
#  5   title         0 non-null        float64
#  6   description   0 non-null        float64
#  7   source        0 non-null        float64
#  8   audience      0 non-null        float64
#  9   created       1536858 non-null  object
#  10  creator       0 non-null        float64
#  11  contributor   0 non-null        float64
#  12  publisher     0 non-null        float64
#  13  license       1537612 non-null  object
#  14  rightsHolder  1537612 non-null  object
#  15  family        1529929 non-null  object
#  16  genus         1524630 non-null  object
#  17  species       1473593 non-null  object
# dtypes: float64(7), int64(1), object(10)
# memory usage: 211.2+ MB

# %%
harvard_df['filepath'] = harvard_df['gbifID'].apply(lambda x: os.path.join(GBIF_HARVARD_INSTALL_PATH, str(x) + ".jpg"))
harvard_df['scientificName'] = harvard_df['family'] + ' ' + harvard_df['genus'] + ' ' + harvard_df['species']
harvard_df.rename(columns={'gbifID': 'image_id'}, inplace=True)

harvard_df.head()
# Out:
#      image_id        type      format  \
# 0  1998300924  StillImage  image/jpeg
# 1  1998300929  StillImage  image/jpeg
# 2  1998300938  StillImage  image/jpeg
# 3  1998300942  StillImage  image/jpeg
# 4  1998300947  StillImage  image/jpeg
#
#                                                                identifier  \
# 0  http://data.huh.harvard.edu/00000e9c-daf6-448a-8e34-047e20d53ea0/image
# 1  http://data.huh.harvard.edu/00007a2a-8077-4473-b043-84aca70b6465/image
# 2  http://data.huh.harvard.edu/0000722a-17cd-44cb-999e-171e8c17a413/image
# 3  http://data.huh.harvard.edu/00002a1a-db77-457c-9763-3700214ff0fc/image
# 4  http://data.huh.harvard.edu/00020ce8-d403-43bd-8a1d-ca3dc6dd461d/image
#
#                                                          references  title  \
# 0  http://data.huh.harvard.edu/00000e9c-daf6-448a-8e34-047e20d53ea0    NaN
# 1  http://data.huh.harvard.edu/00007a2a-8077-4473-b043-84aca70b6465    NaN
# 2  http://data.huh.harvard.edu/0000722a-17cd-44cb-999e-171e8c17a413    NaN
# 3  http://data.huh.harvard.edu/00002a1a-db77-457c-9763-3700214ff0fc    NaN
# 4  http://data.huh.harvard.edu/00020ce8-d403-43bd-8a1d-ca3dc6dd461d    NaN
#
#    description  source  audience           created  creator  contributor  \
# 0          NaN     NaN       NaN  2015-02-03T00:00      NaN          NaN
# 1          NaN     NaN       NaN  2016-01-19T00:00      NaN          NaN
# 2          NaN     NaN       NaN  2017-10-03T00:00      NaN          NaN
# 3          NaN     NaN       NaN  2017-12-05T00:00      NaN          NaN
# 4          NaN     NaN       NaN  2012-01-10T00:00      NaN          NaN
#
#    publisher  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#                                                                     license  \
# 0  https://huh.harvard.edu/access-digital-reproductions-works-public-domain
# 1  https://huh.harvard.edu/access-digital-reproductions-works-public-domain
# 2  https://huh.harvard.edu/access-digital-reproductions-works-public-domain
# 3  https://huh.harvard.edu/access-digital-reproductions-works-public-domain
# 4  https://huh.harvard.edu/access-digital-reproductions-works-public-domain
#
#                                rightsHolder           family           genus  \
# 0  President and Fellows of Harvard College      Viburnaceae        Viburnum
# 1  President and Fellows of Harvard College  Auriculariaceae  Alloexidiopsis
# 2  President and Fellows of Harvard College     Brassicaceae        Boechera
# 3  President and Fellows of Harvard College         Pinaceae           Pinus
# 4  President and Fellows of Harvard College        Myrtaceae        Syzygium
#
#          species  \
# 0    acerifolium
# 1         calcea
# 2        stricta
# 3         rigida
# 4  korthalsianum
#
#                                                         filepath  \
# 0  /projectnb/herbdl/data/harvard-herbaria/images/1998300924.jpg
# 1  /projectnb/herbdl/data/harvard-herbaria/images/1998300929.jpg
# 2  /projectnb/herbdl/data/harvard-herbaria/images/1998300938.jpg
# 3  /projectnb/herbdl/data/harvard-herbaria/images/1998300942.jpg
# 4  /projectnb/herbdl/data/harvard-herbaria/images/1998300947.jpg
#
#                           scientificName
# 0       Viburnaceae Viburnum acerifolium
# 1  Auriculariaceae Alloexidiopsis calcea
# 2          Brassicaceae Boechera stricta
# 3                  Pinaceae Pinus rigida
# 4       Myrtaceae Syzygium korthalsianum

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

harvard_df['scientificNameEncoded'] = le.fit_transform(harvard_df['scientificName'])

# %%
harvard_df = harvard_df[['image_id', 'filepath', 'scientificName', 'scientificNameEncoded', 'family', 'genus', 'species']]

harvard_df.to_csv("/projectnb/herbdl/data/harvard-herbaria/index.csv", index=False)

# %% [markdown]
# ## GBIF F24

# %%
gbif24_multimedia = pd.read_csv("/projectnb/herbdl/data/GBIF-F24/multimedia.txt", delimiter="\t", on_bad_lines='warn')
occurrence_df = pd.read_csv("/projectnb/herbdl/data/GBIF-F24/occurrence.txt", delimiter="\t", on_bad_lines='warn')

print(f"Number of samples in GBIF F24 dataset: {len(gbif24_multimedia)}")
# Out:
# /scratch/545462.1.cds/ipykernel_1068295/2827518963.py:1: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   gbif24_multimedia = pd.read_csv("/projectnb/herbdl/data/GBIF-F24/multimedia.txt", delimiter="\t", on_bad_lines='warn')
# Skipping line 9170: expected 223 fields, saw 264
#
# Skipping line 106385: expected 223 fields, saw 264
#
# Skipping line 144579: expected 223 fields, saw 264
#
# Skipping line 186889: expected 223 fields, saw 315
#
# Skipping line 269825: expected 223 fields, saw 252
#
# Skipping line 300458: expected 223 fields, saw 265
#
# Skipping line 414444: expected 223 fields, saw 274
#
# Skipping line 477015: expected 223 fields, saw 274
#
# Skipping line 532575: expected 223 fields, saw 315
#
# Skipping line 571831: expected 223 fields, saw 315
#
# Skipping line 751188: expected 223 fields, saw 252
#
# Skipping line 780885: expected 223 fields, saw 292
#
# Skipping line 797125: expected 223 fields, saw 274
#
# Skipping line 858887: expected 223 fields, saw 241
#
# Skipping line 919178: expected 223 fields, saw 264
#
# Skipping line 976941: expected 223 fields, saw 241
#
# Skipping line 1077848: expected 223 fields, saw 274
#
# Skipping line 1156040: expected 223 fields, saw 274
#
# Skipping line 1214029: expected 223 fields, saw 315
# Skipping line 1216164: expected 223 fields, saw 252
#
# Skipping line 1226020: expected 223 fields, saw 274
#
# Skipping line 1241418: expected 223 fields, saw 315
# Skipping line 1241977: expected 223 fields, saw 264
#
# Skipping line 1257367: expected 223 fields, saw 274
#
# Skipping line 1291000: expected 223 fields, saw 315
#
# Skipping line 1313011: expected 223 fields, saw 274
#
# Skipping line 1354955: expected 223 fields, saw 292
#
# Skipping line 1369278: expected 223 fields, saw 246
# Skipping line 1371045: expected 223 fields, saw 274
#
# Skipping line 1435127: expected 223 fields, saw 252
#
# Skipping line 1441952: expected 223 fields, saw 274
#
# Skipping line 1449133: expected 223 fields, saw 292
#
# Skipping line 1513085: expected 223 fields, saw 274
#
# Skipping line 1534372: expected 223 fields, saw 274
#
# Skipping line 1546070: expected 223 fields, saw 252
#
# Skipping line 1557766: expected 223 fields, saw 274
#
# Skipping line 1570312: expected 223 fields, saw 264
#
# Skipping line 1678691: expected 223 fields, saw 252
#
# Skipping line 1698955: expected 223 fields, saw 292
#
# Skipping line 1711352: expected 223 fields, saw 315
#
# Skipping line 1734938: expected 223 fields, saw 315
#
# Skipping line 1791757: expected 223 fields, saw 224
#
# Skipping line 1802149: expected 223 fields, saw 246
#
# Skipping line 1832562: expected 223 fields, saw 264
#
# Skipping line 1889670: expected 223 fields, saw 315
#
# Skipping line 1924925: expected 223 fields, saw 292
#
# Skipping line 1938258: expected 223 fields, saw 274
#
# Skipping line 1941899: expected 223 fields, saw 266
#
# Skipping line 1992319: expected 223 fields, saw 274
#
# Skipping line 2040676: expected 223 fields, saw 315
#
# Skipping line 2069621: expected 223 fields, saw 274
#
# Skipping line 2107204: expected 223 fields, saw 264
#
# Skipping line 2135440: expected 223 fields, saw 252
#
# Skipping line 2148652: expected 223 fields, saw 252
#
# Skipping line 2169492: expected 223 fields, saw 315
#
# Skipping line 2196511: expected 223 fields, saw 274
#
# Skipping line 2238307: expected 223 fields, saw 252
#
# Skipping line 2260616: expected 223 fields, saw 315
#
# Skipping line 2266113: expected 223 fields, saw 274
# Skipping line 2268484: expected 223 fields, saw 274
#
# Skipping line 2365164: expected 223 fields, saw 315
#
# Skipping line 2425676: expected 223 fields, saw 274
#
# Skipping line 2448633: expected 223 fields, saw 274
# Skipping line 2449342: expected 223 fields, saw 274
#
# Skipping line 2454618: expected 223 fields, saw 292
#
# Skipping line 2510912: expected 223 fields, saw 252
#
# Skipping line 2530275: expected 223 fields, saw 274
#
# Skipping line 2575013: expected 223 fields, saw 274
# Skipping line 2575507: expected 223 fields, saw 274
#
# Skipping line 2588765: expected 223 fields, saw 274
# Skipping line 2592705: expected 223 fields, saw 274
#
# Skipping line 2626207: expected 223 fields, saw 245
#
# Skipping line 2632371: expected 223 fields, saw 315
#
# Skipping line 2646524: expected 223 fields, saw 274
#
# Skipping line 2655199: expected 223 fields, saw 274
#
# Skipping line 2675219: expected 223 fields, saw 315
#
# Skipping line 2679343: expected 223 fields, saw 274
# Skipping line 2679345: expected 223 fields, saw 274
#
# Skipping line 2717088: expected 223 fields, saw 315
#
# Skipping line 2719876: expected 223 fields, saw 241
#
# Skipping line 2755456: expected 223 fields, saw 315
#
# Skipping line 2764059: expected 223 fields, saw 274
#
# Skipping line 2777072: expected 223 fields, saw 274
#
# Skipping line 2790960: expected 223 fields, saw 274
#
# Skipping line 2884554: expected 223 fields, saw 274
#
# Skipping line 2903286: expected 223 fields, saw 315
#
# Skipping line 2907996: expected 223 fields, saw 315
#
# Skipping line 2917536: expected 223 fields, saw 315
#
# Skipping line 2922936: expected 223 fields, saw 274
#
# Skipping line 2939227: expected 223 fields, saw 252
#
# Skipping line 2970905: expected 223 fields, saw 274
#
# Skipping line 2975198: expected 223 fields, saw 274
#
# Skipping line 2978981: expected 223 fields, saw 274
#
# Skipping line 3010294: expected 223 fields, saw 264
#
# Skipping line 3105169: expected 223 fields, saw 242
#
# Skipping line 3210186: expected 223 fields, saw 274
#
# Skipping line 3229541: expected 223 fields, saw 252
#
# Skipping line 3242194: expected 223 fields, saw 315
#
# Skipping line 3259670: expected 223 fields, saw 274
#
# Skipping line 3337744: expected 223 fields, saw 264
#
# Skipping line 3490848: expected 223 fields, saw 246
#
# Skipping line 3525546: expected 223 fields, saw 264
#
# Skipping line 3576559: expected 223 fields, saw 274
#
# Skipping line 3600940: expected 223 fields, saw 274
#
# Skipping line 3622905: expected 223 fields, saw 274
#
# Skipping line 3630119: expected 223 fields, saw 315
#
# Skipping line 3703852: expected 223 fields, saw 315
# Skipping line 3706761: expected 223 fields, saw 274
#
# Skipping line 3731114: expected 223 fields, saw 274
#
# Skipping line 3744616: expected 223 fields, saw 274
#
# Skipping line 3756134: expected 223 fields, saw 315
#
# Skipping line 3800203: expected 223 fields, saw 266
#
# Skipping line 3806868: expected 223 fields, saw 249
#
# Skipping line 3850736: expected 223 fields, saw 315
#
# Skipping line 3856469: expected 223 fields, saw 274
#
# Skipping line 3877459: expected 223 fields, saw 274
#
# Skipping line 3972538: expected 223 fields, saw 241
#
# Skipping line 3998061: expected 223 fields, saw 274
#
# Skipping line 4020644: expected 223 fields, saw 264
#
# Skipping line 4047432: expected 223 fields, saw 246
#
# Skipping line 4052801: expected 223 fields, saw 264
#
# Skipping line 4120241: expected 223 fields, saw 266
#
# Skipping line 4254454: expected 223 fields, saw 274
# Skipping line 4254871: expected 223 fields, saw 315
#
# /scratch/545462.1.cds/ipykernel_1068295/2827518963.py:2: DtypeWarning: Columns (1,2,3,7,8,9,10,11,15,16,18,20,21,22,29,30,31,38,40,41,42,45,46,47,48,49,50,55,56,57,59,60,61,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,81,82,83,86,87,89,90,91,92,93,94,95,96,97,98,99,100,102,103,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,135,137,138,139,140,141,142,143,144,145,146,147,149,150,151,152,153,154,155,160,162,163,164,167,168,171,173,174,175,177,178,182,183,184,185,186,188,189,190,191,192,193,194,195,196,197,198,199,200,204,208,210,211,214,215,216,217,218,219,220,221) have mixed types. Specify dtype option on import or set low_memory=False.
#   occurrence_df = pd.read_csv("/projectnb/herbdl/data/GBIF-F24/occurrence.txt", delimiter="\t", on_bad_lines='warn')
# Number of samples in GBIF F24 dataset: 3841950

# %%
occurrence_df = occurrence_df[['gbifID', 'family', 'genus', 'species']]
occurrence_df['species'] = occurrence_df['species'].str.split(' ').str[-1]

occurrence_df.head()
# Out:
#        gbifID         family         genus       species
# 0  1989366853  Euphorbiaceae     Euphorbia  heterophylla
# 1  3060576010  Malpighiaceae     Byrsonima       riparia
# 2  4900443071       Fagaceae       Quercus         acuta
# 3  1989367109      Myrtaceae     Melaleuca   leucadendra
# 4  1989366149     Cyperaceae  Trichophorum       alpinum

# %%
occurrence_df.shape, gbif24_multimedia.shape
# Out:
# ((4495862, 4), (3841950, 15))

# %%
len(gbif24_multimedia) - (occurrence_df['gbifID'].isin(gbif24_multimedia['gbifID']).sum())
# Out:
# 92242

# %%
gbif24_df = gbif24_multimedia.merge(occurrence_df, on='gbifID', how='left')
gbif24_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3841950 entries, 0 to 3841949
# Data columns (total 18 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   gbifID        int64
#  1   type          object
#  2   format        object
#  3   identifier    object
#  4   references    object
#  5   title         float64
#  6   description   object
#  7   source        float64
#  8   audience      float64
#  9   created       float64
#  10  creator       object
#  11  contributor   float64
#  12  publisher     float64
#  13  license       object
#  14  rightsHolder  object
#  15  family        object
#  16  genus         object
#  17  species       object
# dtypes: float64(6), int64(1), object(11)
# memory usage: 527.6+ MB

# %%
os.listdir("/projectnb/herbdl/data/GBIF-F24/IMAGES")
# Out:
# ['1928842606.jpg',
#  '1930787013.jpg',
#  '3898417055.jpg',
#  '1929358132.jpg',
#  '1928982806.jpg',
#  '1927955550.jpg',
#  '1928074588.jpg',
#  '1930488863.jpg',
#  '1988823081.jpg',
#  '1928563722.jpg',
#  '2423971764.jpg',
#  '1989407488.jpg',
#  '1928247955.jpg',
#  '2273850795.jpg',
#  '3898424251.jpg',
#  '2561146932.jpg',
#  '1930151213.jpg',
#  '1930181036.jpg',
#  '2573383832.jpg',
#  '1949820619.jpg',
#  '3041317837.jpg',
#  '1930163846.jpg',
#  '1989403513.jpg',
#  '3005824301.jpg',
#  '1928582257.jpg',
#  '1930934856.jpg',
#  '1988797327.jpg',
#  '1930043862.jpg',
#  '2573491989.jpg',
#  '1930383810.jpg',
#  '1989384968.jpg',
#  '3467740377.jpg',
#  '1928418119.jpg',
#  '4439066661.jpg',
#  '1929055634.jpg',
#  '1930245095.jpg',
#  '2447355209.jpg',
#  '1929298483.jpg',
#  '1989526022.jpg',
#  '1930185323.jpg',
#  '1928330693.jpg',
#  '2235422659.jpg',
#  '3422280433.jpg',
#  '1931372766.jpg',
#  '1988637826.jpg',
#  '2251704674.jpg',
#  '3041325541.jpg',
#  '1928434551.jpg',
#  '1929763096.jpg',
#  '3467740418.jpg',
#  '1931379469.jpg',
#  '1928263683.jpg',
#  '1929182495.jpg',
#  '1930109508.jpg',
#  '1929182278.jpg',
#  '1930717317.jpg',
#  '1927888841.jpg',
#  '1930107445.jpg',
#  '1928949605.jpg',
#  '1988920956.jpg',
#  '3898412395.jpg',
#  '1930922794.jpg',
#  '1928368220.jpg',
#  '1989193799.jpg',
#  '1931055101.jpg',
#  '1988608932.jpg',
#  ...]

# %%
from sklearn.preprocessing import LabelEncoder


gbif24_df['filepath'] = gbif24_df['gbifID'].apply(lambda x: os.path.join("/projectnb/herbdl/data/GBIF-F24/IMAGES", str(x) + ".jpg"))
gbif24_df['scientificName'] = gbif24_df['family'] + ' ' + gbif24_df['genus'] + ' ' + gbif24_df['species']

le = LabelEncoder()
gbif24_df['scientificNameEncoded'] = le.fit_transform(gbif24_df['scientificName'])

gbif24_df.rename(columns={'gbifID': 'image_id'}, inplace=True)

gbif24_df.head()
# Out:
#      image_id        type      format  \
# 0  1927768154  StillImage  image/jpeg
# 1  1927768159  StillImage  image/jpeg
# 2  1927768172  StillImage  image/jpeg
# 3  1927768186  StillImage  image/jpeg
# 4  1927768190  StillImage  image/jpeg
#
#                                                     identifier references  \
# 0       http://sweetgum.nybg.org/images3/3065/424/03698350.jpg        NaN
# 1       http://sweetgum.nybg.org/images3/3143/170/03554084.jpg        NaN
# 2        http://sweetgum.nybg.org/images3/635/056/00039029.jpg        NaN
# 3  http://sweetgum.nybg.org/images3/393/524/v-035-01297411.jpg        NaN
# 4        http://sweetgum.nybg.org/images3/714/539/01497227.jpg        NaN
#
#    title description  source  audience  created  \
# 0    NaN         NaN     NaN       NaN      NaN
# 1    NaN         NaN     NaN       NaN      NaN
# 2    NaN         NaN     NaN       NaN      NaN
# 3    NaN         NaN     NaN       NaN      NaN
# 4    NaN         NaN     NaN       NaN      NaN
#
#                          creator  contributor  publisher  \
# 0  The New York Botanical Garden          NaN        NaN
# 1  The New York Botanical Garden          NaN        NaN
# 2  The New York Botanical Garden          NaN        NaN
# 3  The New York Botanical Garden          NaN        NaN
# 4  The New York Botanical Garden          NaN        NaN
#
#                                        license                   rightsHolder  \
# 0  http://creativecommons.org/licenses/by/4.0/  The New York Botanical Garden
# 1  http://creativecommons.org/licenses/by/4.0/  The New York Botanical Garden
# 2  http://creativecommons.org/licenses/by/4.0/  The New York Botanical Garden
# 3  http://creativecommons.org/licenses/by/4.0/  The New York Botanical Garden
# 4  http://creativecommons.org/licenses/by/4.0/  The New York Botanical Garden
#
#         family         genus          species  \
# 0   Cyperaceae         Carex           lurida
# 1  Osmundaceae  Osmundastrum      cinnamomeum
# 2     Fagaceae       Quercus       xalapensis
# 3   Cyperaceae  Rhynchospora        contracta
# 4  Primulaceae      Wallenia  subverticillata
#
#                                                 filepath  \
# 0  /projectnb/herbdl/data/GBIF-F24/IMAGES/1927768154.jpg
# 1  /projectnb/herbdl/data/GBIF-F24/IMAGES/1927768159.jpg
# 2  /projectnb/herbdl/data/GBIF-F24/IMAGES/1927768172.jpg
# 3  /projectnb/herbdl/data/GBIF-F24/IMAGES/1927768186.jpg
# 4  /projectnb/herbdl/data/GBIF-F24/IMAGES/1927768190.jpg
#
#                          scientificName  scientificNameEncoded
# 0               Cyperaceae Carex lurida                  45197
# 1  Osmundaceae Osmundastrum cinnamomeum                 103317
# 2           Fagaceae Quercus xalapensis                  68964
# 3     Cyperaceae Rhynchospora contracta                  47094
# 4  Primulaceae Wallenia subverticillata                 119706

# %%
gbif24_df = gbif24_df[['image_id', 'filepath', 'scientificName', 'scientificNameEncoded', 'family', 'genus', 'species', 'creator']]

gbif24_df.to_csv("/projectnb/herbdl/data/GBIF-F24/index.csv", index=False)

# %% [markdown]
# ## Master Index

# %%
import pandas as pd

harvard_index = pd.read_csv("/projectnb/herbdl/data/harvard-herbaria/index.csv")
gbif_f24_index = pd.read_csv("/projectnb/herbdl/data/GBIF-F24/index.csv")
kaggle_index = pd.read_csv("/projectnb/herbdl/data/kaggle-herbaria/index.csv")
# Out:
# /scratch/730567.1.cds/ipykernel_2146176/4061572314.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   kaggle_index = pd.read_csv("/projectnb/herbdl/data/kaggle-herbaria/index.csv")

# %%
master_index['scientificName'].nunique()
# Out:
# 192147

# %%
gbif_f24_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3841950 entries, 0 to 3841949
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   image_id               int64
#  1   filepath               object
#  2   scientificName         object
#  3   scientificNameEncoded  int64
#  4   family                 object
#  5   genus                  object
#  6   species                object
#  7   creator                object
# dtypes: int64(2), object(6)
# memory usage: 234.5+ MB

# %%
kaggle_index['creator'] = None

# %%
kaggle_index.drop("caption", axis=1, inplace=True, errors="ignore")

# %%
print("Columns:")
print(f"Harvard GBIF: {harvard_index.columns.tolist()}")
print(f"GBIF F24: {gbif_f24_index.columns.tolist()}")
print(f"Kaggle Herbarium: {kaggle_index.columns.tolist()}")
# Out:
# Columns:
# Harvard GBIF: ['image_id', 'filepath', 'scientificName', 'scientificNameEncoded', 'family', 'genus', 'species']
# GBIF F24: ['image_id', 'filepath', 'scientificName', 'scientificNameEncoded', 'family', 'genus', 'species', 'creator']
# Kaggle Herbarium: ['image_id', 'filepath', 'scientificName', 'family', 'genus', 'species', 'scientificNameEncoded', 'creator']

# %%
master_index = pd.concat([harvard_index, gbif_f24_index, kaggle_index]).reset_index(drop=True)
master_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8247878 entries, 0 to 8247877
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   image_id               object
#  1   filepath               object
#  2   scientificName         object
#  3   scientificNameEncoded  int64
#  4   family                 object
#  5   genus                  object
#  6   species                object
#  7   creator                object
# dtypes: int64(1), object(7)
# memory usage: 503.4+ MB

# %%
master_index.to_csv("/projectnb/herbdl/data/master_index.csv", index=False)

# %%
kaggle_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2868316 entries, 0 to 2868315
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   image_id               object
#  1   filepath               object
#  2   scientificName         object
#  3   family                 object
#  4   genus                  object
#  5   species                object
#  6   scientificNameEncoded  int64
#  7   creator                object
# dtypes: int64(1), object(7)
# memory usage: 175.1+ MB
